# %% [markdown]
# ## Histograma
# Muestra la distribución de una varible numérica como un conjunto de datos. Los datos numéricos se agrupan en "bins" (clases o grupos) según un rango de valores.. Cada "bin" va a tener una barra. La altura de la barra representa cuantos puntos de datos existen dentro del rango del "bin". Usualmente es el primer gráfico a realizar de todas las columnas numéricas de mi dataset ya que me dice como se distribuyen mis datos. Esto, por ejemplo, me permite escoger pruebas estadísticas correctas que asumen cierta distribución. Este es el primer gráfico que analizamos en esta parte práctica que nos permitirá ver la forma de una distribución.
#
# **Eje X**: Rango o Bins de la variable numérica
# **Eje Y**: Frecuencia absoluta o relativa de cada "bin"
# **Otros nombres**: Histogram
#
# ![image.png](attachment:26207242-96f9-4c60-b55e-114ba48957aa.png)

# %% [markdown]
# #### Cuando Utilizar
# - Cuando quiero observar cómo se distribuyen mis datos
# - Cuando quiero observar la forma de la distribución de mis datos (ejemplo: normal, sesgada, uniforme, bimodal, multimodal)
#
# #### Consejos
# - Siempre la base del eje Y tiene que ser cero
# - Elegimos un número de "bins" que me permita observar la verdadera distribución. Elegir un número muy pequeño de bins puede darme resultados engañosos.
# - El rango de cada uno de los "bins" tiene que ser exactamente el mismo. Es decir, si el primer bin va a contener la frecuencia de los valores entre 5 a 10, el segundo bin tiene que ser de 10 a 15, el siguiente de 15 a 20, y así sucesivamente hasta cubrir todo mi rando de valores numéricos posibles de la variable analizada.
# - Barras verticales o horizontales? No hay preferencia. Usualmente verticales.
# - Recuerda que no tiene sentido hallar distribuciones de variables categóricas. Para esto se utiliza un simple diagrama de barras que cuente cuántos puntos caen en cada categoría.
#
# ## En esta clase
# #### Datos
# Información sobre los pasajeros del titanic
#
# #### Objetivo
# 1. Cómo es la distribución de edades de Hombres y Mujeres?
# 2. Cómo es la distribución de precio pagado por los pasajes en el titanic?
#
# #### Referencias
# - https://github.com/lkuffo/data-viz/blob/main/NIVEL1/4_histograma.ipynb
# - https://datavizcatalogue.com/ES/metodos/histograma.html
# - https://es.wikipedia.org/wiki/Histograma
# - https://chartio.com/learn/charts/histogram-complete-guide/

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Leemos los datos con pandas
df = pd.read_csv('./data/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Elimino los valores nulos de la edad
df = df.dropna(subset=['Age'], axis='index')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.hist(
    'Age'
)
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
# Modificando los bins
df.hist(
    'Age',
    bins=20
)
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
# Dividir por sexos
df.hist(
    'Age',
    by='Sex',
    bins=15
)
# Out:
# array([<Axes: title={'center': 'female'}>,
#        <Axes: title={'center': 'male'}>], dtype=object)

# %% [markdown]
# ## Kernel Density Estimator (KDE)
# En el histograma es a veces complicado visualizar la forma de mi distribución. El Kernel Density Estimator crea una curva/función de probabilidad basado en la distribución de mis datos. Se lo puede resumir como un suavizado del histograma, sin embargo, estadísticamente tiene una representación más compleja. En breves palabras, crea una curva que me indica en el Eje Y la probabilidad de que una nueva observación de esa variable tenga ese valor del Eje X. Usulamente se lo presenta en el mismo gráfico que el Histograma.
#
# **Eje X**: Rango de la variable numérica.
# **Eje Y**: Probabilidad de que un nuevo punto tenga ese valor.
#
# ![image.png](attachment:5aefe692-25a9-4e46-a8be-57a08ac3f41e.png)
#
# #### Cuando utilizar
# - Cuando quiero observar cómo se distribuyen mis datos
# - Cuando quiero observar la forma de la distribución de mis datos (ejemplo: normal, sesgada, uniforme, bimodal, multimodal)
# - Cuando quiero representar un Histograma de una forma más profesional
#
# #### Consejos
# - Los mismos del Histograma
# - Es visto como un gráfico bastante profesional.
#
# #### Referencias
# - https://datavizcatalogue.com/ES/metodos/grafico_de_densidad.html
# - https://en.wikipedia.org/wiki/Kernel_density_estimation
# - La explicación en detalle del KDE: https://towardsdatascience.com/histograms-vs-kdes-explained-ed62e7753f12

# %%
# Solo se puede hacer con seaborn
import seaborn as sns

# %%
sns.histplot(
    df,
    x='Age'
)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(
    df,
    x='Age',
    kde=True,
    bins= 20
)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# Probabilidad del KDE
sns.histplot(
    df,
    x='Age',
    kde=True,
    bins= 20,
    stat='probability'
)
# Out:
# <Axes: xlabel='Age', ylabel='Probability'>

# %%
# por Sexo
sns.histplot(
    df,
    x='Age',
    kde=True,
    bins= 20,
    hue='Sex'
)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Histograma Acumulativo
# Permite observar la distribución de los datos desde otro punto de vista.

# %%
sns.histplot(
    df,
    x='Age',
    cumulative=True,
    bins= 20,
    fill=False
)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(
    df,
    x='Age',
    cumulative=True,
    bins= 20,
    fill=False,
    element='step'
)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>
