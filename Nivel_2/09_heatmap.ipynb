# %% [markdown]
# ## Heatmap (Mapa de Calor)
# Es un gráfico X vs Y con dos usos diferentes dependiendo del tipo de las variables en los ejes.
#
# **Si las dos variables son numéricas:** El heatmap es una matriz que representa como se distribuyen las dos variables viéndolas como un par de puntos. Es decir, que par de valores (x,y) tienen una mayor o menor frecuencia. Lo podemos ver como un Scatter Plot agrupado en cuadrículas equidistantes. En donde una cuadrícula con una tonalidad más oscura me indica que existen más de esos pares de puntos (x,y) dentro de esa cuadrícula. Y una cuadrícula con una tonalidad más clara que indica que existen menos pares de puntos (x,y) dentro de esa cuadrícula. Por lo general, se lo utiliza cuando tengo un Scatter Plot con demasiados puntos o cuando quiero tener información sobre la distribución de las variables como un par. Y no individualmente.
# **Otros nombres**: Si las cuadrículas son hexagonales, se le denomina Hexabin. Y la funcionalidad es la misma.
#
# ![image.png](attachment:d383cd62-a2e5-4a39-aeb0-f9ae150c1fde.png)
#
# **Si las dos variables son categóricas y codifican una variable numérica**: El Heatmap es una matriz con tantas celdas como valores distintos categóricos tenga en X y en Y. Una celda con una tonalidad más oscura me indica que el valor de ese punto X vs Y es mayor. **Ejemplos de Uso**: Como dueño de un supermercado me gustaría saber qué tipo de productos se han vendido más y en cuales supermercados. En este caso mi eje X serían los tipos de productos, mi eje Y serían los nombres de los supermercados, y la celda con su intensidad de color codificarían el valor de ventas de ese produto en ese supermercado.
#
# ![image.png](attachment:7b7cd1f2-e542-48c5-96f7-5d09f1b2c244.png)
#
# **Otros Nombres**:
# Existe algo denominado Heatmap de Correlaciones o Matriz de Correlación. En donde ambos ejes tienen nombres de variables (o columnas). Y la celda muestra el coeficiente de correlación entre esas dos variables.
#
# ![image.png](attachment:aa6f55f5-f83d-46e2-ba1f-8c40fe700ba3.png)
#
# Otro ejemplo de un Heatmap seria el grafico del número de contribuciones de un usuario de Github. Rápidamente podemos ver que dias hemos hecho mas contribuciones. Es un gráfico muy intuitivo y útil para mostrar una cantidad grande de información de forma efectiva.
#
# ![image.png](attachment:5c1aedad-9297-4124-81fa-882774809d46.png)
#
# #### Cuándo Utilizar
#
# - Cuando quiero observar la distribución de dos variables como un par de puntos.
# - Cuando quiero visualizar de forma intuitiva mucha información de una gran cantidad de categorías en un solo gráfico.
#
# #### Consejos
# - Usualmente la tonalidad más oscura representará un mayor valor.
# - Es recomendable añadir una leyenda que muestre el significado de las tonalidades. Los rangos de valores que cada tonalidad codifica.
# - Cuando utilizamos variables categóricas es comúm mostrar el valor que codifica la celda dentro de la celda.
# - Es una alternativa cuando quiero hacer un gráfico de barras múltiples, y tengo muchas categorías. Como el ejemplo que mencionamos. Si tengo muchos supermercados, o muchos tipos de productos diferentes. Un gráfico de barras será demasiado denso.
# - Si tengo muy pocos puntos en mi dataset, es preferible un scatter plot. O si tengo solo una o dos categorías es mejor un diagrama de barras.
#
# ### En esta clase
#
# #### Datos
# Información sobre especies de pingüinos. Información sobre venta de tiendas.
#
# #### Objetivos
# 1. Encontrar alguna correlación entre las características se los pingüinos.
# 2. Mostrar difrencias de magnitud entre cuántos pingüinos viven en cuáles islas.
# 3. Halla cómo ha sido la diferencia de ventas en las tiendas 3, 44, 45, 46, 47, 48, 49, 50 a lo largo de los meses.
#
# ### Referencias
# - https://datavizcatalogue.com/ES/metodos/mapa_de_calor.html
# - https://chartio.com/learn/charts/heatmap-complete-guide/
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.hexbin.html
# - https://seaborn.pydata.org/generated/seaborn.jointplot.html

# %%
 import pandas as pd

# %%
df = pd.read_csv('../data/pinguinos.csv')
df = df.dropna()
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
import seaborn as sns

# %%
# Heatmap con jointplot

sns.jointplot(
    data=df,
    x='flipper_length_mm',
    y='culmen_length_mm',
    kind='hist',
    joint_kws={
        'bins':20
    },
    marginal_kws={
        'bins': 20,
        'fill': False
    },
    # cbar=True, # Muestra la leyenda de la barra de colores
)

# %%
sns.jointplot(
    data=df,
    x='flipper_length_mm',
    y='culmen_length_mm',
    kind='hex',
    joint_kws={
        'bins':20
    },
    marginal_kws={
        'bins': 20,
        'fill': False
    },
    # cbar=True, # Muestra la leyenda de la barra de colores
    gridsize=30
)

# %%
# Otra forma de hace un heatmap

df.plot.hexbin(
    x='flipper_length_mm',
    y='culmen_length_mm',
    gridsize=30
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='culmen_length_mm'>

# %% [markdown]
# ## Heatmap Categórico

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/tienda_ventas.csv')
df = df.dropna()
df
# Out:
#               id        date  store_nbr                      family  \
# 0              0  2013-01-01          1                  AUTOMOTIVE
# 1              1  2013-01-01          1                   BABY CARE
# 2              2  2013-01-01          1                      BEAUTY
# 3              3  2013-01-01          1                   BEVERAGES
# 4              4  2013-01-01          1                       BOOKS
# ...          ...         ...        ...                         ...
# 2161561  2161561  2016-04-30          9                     POULTRY
# 2161562  2161562  2016-04-30          9              PREPARED FOODS
# 2161563  2161563  2016-04-30          9                     PRODUCE
# 2161564  2161564  2016-04-30          9  SCHOOL AND OFFICE SUPPLIES
# 2161565  2161565  2016-04-30          9                     SEAFOOD
#
#               sales  onpromotion
# 0           0.00000            0
# 1           0.00000            0
# 2           0.00000            0
# ...

# %%
# Creamos una nueva columna con el año y el mes
df['periodo'] = df['date'].apply(lambda x: x[:7])
df
# Out:
#               id        date  store_nbr                      family  \
# 0              0  2013-01-01          1                  AUTOMOTIVE
# 1              1  2013-01-01          1                   BABY CARE
# 2              2  2013-01-01          1                      BEAUTY
# 3              3  2013-01-01          1                   BEVERAGES
# 4              4  2013-01-01          1                       BOOKS
# ...          ...         ...        ...                         ...
# 2161561  2161561  2016-04-30          9                     POULTRY
# 2161562  2161562  2016-04-30          9              PREPARED FOODS
# 2161563  2161563  2016-04-30          9                     PRODUCE
# 2161564  2161564  2016-04-30          9  SCHOOL AND OFFICE SUPPLIES
# 2161565  2161565  2016-04-30          9                     SEAFOOD
#
#               sales  onpromotion  periodo
# 0           0.00000            0  2013-01
# 1           0.00000            0  2013-01
# ...

# %%
# Filtramos las tiendas 4, 44, 45, 46, 47, 48, 49, 50
df2 = df[df['store_nbr'].isin([4, 44, 45, 46, 47, 48, 49, 50])]
df2
# Out:
#               id        date  store_nbr                      family  \
# 1089        1089  2013-01-01          4                  AUTOMOTIVE
# 1090        1090  2013-01-01          4                   BABY CARE
# 1091        1091  2013-01-01          4                      BEAUTY
# 1092        1092  2013-01-01          4                   BEVERAGES
# 1093        1093  2013-01-01          4                       BOOKS
# ...          ...         ...        ...                         ...
# 2161297  2161297  2016-04-30         50                     POULTRY
# 2161298  2161298  2016-04-30         50              PREPARED FOODS
# 2161299  2161299  2016-04-30         50                     PRODUCE
# 2161300  2161300  2016-04-30         50  SCHOOL AND OFFICE SUPPLIES
# 2161301  2161301  2016-04-30         50                     SEAFOOD
#
#               sales  onpromotion  periodo
# 1089        0.00000            0  2013-01
# 1090        0.00000            0  2013-01
# ...

# %%
# Agrupamos por las ventas por periodos de cada tienda.
df2_agrupado = df2.groupby(['periodo', 'store_nbr']).agg({
    'sales': 'sum'
})
df2_agrupado
# Out:
#                           sales
# periodo store_nbr
# 2013-01 4          2.092959e+05
#         44         6.763951e+05
#         45         5.394207e+05
#         46         4.851985e+05
#         47         5.328300e+05
# ...                         ...
# 2016-04 46         9.085644e+05
#         47         1.158896e+06
#         48         7.901695e+05
#         49         1.100845e+06
#         50         6.022959e+05
#
# [320 rows x 1 columns]

# %%
df2_agrupado = df2_agrupado.unstack()
df2_agrupado
# Out:
#                    sales                                            \
# store_nbr             4             44            45            46
# periodo
# 2013-01    209295.859959  6.763951e+05  5.394207e+05  4.851985e+05
# 2013-02    183875.168026  5.955276e+05  5.034798e+05  4.469718e+05
# 2013-03    222346.659981  6.973039e+05  6.015846e+05  5.316344e+05
# 2013-04    208460.129010  6.669542e+05  5.572005e+05  4.865555e+05
# 2013-05    214306.581983  6.726814e+05  5.764108e+05  5.023400e+05
# 2013-06    219865.072982  6.663036e+05  5.914544e+05  5.101676e+05
# 2013-07    211088.040113  6.375686e+05  5.542560e+05  4.807294e+05
# 2013-08    205759.032001  6.541044e+05  5.657099e+05  5.007798e+05
# 2013-09    216418.160946  6.857152e+05  5.858765e+05  5.159002e+05
# 2013-10    217640.924066  6.645889e+05  5.797002e+05  5.051654e+05
# 2013-11    226832.862029  7.927187e+05  6.321858e+05  5.404963e+05
# 2013-12    276093.641047  9.174606e+05  8.115263e+05  7.357556e+05
# ...

# %%
matriz = df2_agrupado.transpose()
matriz
# Out:
# periodo                2013-01        2013-02        2013-03        2013-04  \
#       store_nbr
# sales 4          209295.859959  183875.168026  222346.659981  208460.129010
#       44         676395.138954  595527.551012  697303.868000  666954.222780
#       45         539420.676079  503479.819965  601584.635970  557200.458882
#       46         485198.490116  446971.842070  531634.404456  486555.474044
#       47         532830.024953  477916.973850  578854.175901  524800.597078
#       48         393039.644168  369976.821263  447756.715286  413425.020003
#       49         291891.128982  258320.141966  325003.586018  312894.258091
#       50         341249.754079  323027.227966  374337.286047  348366.691837
#
# periodo                2013-05        2013-06        2013-07        2013-08  \
#       store_nbr
# sales 4          214306.581983  219865.072982  211088.040113  205759.032001
#       44         672681.377906  666303.585030  637568.579971  654104.371982
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(
    figsize=(15, 8)
)

sns.heatmap( # Solo para variables categóricas
    matriz,
    cmap='Blues', # Cambia a escalation de azules
    square=True,
    linewidth=0.1,
    # annot=True para poner el valor dentro de cada casilla, no se pone aquí porque los valores son grandes
)
# Out:
# <Axes: xlabel='periodo', ylabel='None-store_nbr'>

# %% [markdown]
# ## Heatmap de correlación
# - Es un heatmap que muestra el nivel de correlación entre diferentes columnas de mi dataframe. Siempre será una matriz cuadrada.
# - Es un buen acompañante del gráfico de pairplot para ver correlaciones.
# - Es una gráfica que puede usarse como punto de partida de la investigación de variables numéricas.
#
# ### Cuándo utilizar?
# - Cuando quiero detectar rápidamente en una sola, vista todos los coeficientes de correlación entre las variables de mi Dataset.

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/pinguinos.csv')
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
# Limpiamos los datos nulos
df = df.dropna()
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
# Creamos un dataframe con las variables que vamos a correlacionar
df_filtrado = df[['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g']]
df_filtrado
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# 0                39.1             18.7              181.0       3750.0
# 1                39.5             17.4              186.0       3800.0
# 2                40.3             18.0              195.0       3250.0
# 4                36.7             19.3              193.0       3450.0
# 5                39.3             20.6              190.0       3650.0
# ..                ...              ...                ...          ...
# 338              47.2             13.7              214.0       4925.0
# 340              46.8             14.3              215.0       4850.0
# 341              50.4             15.7              222.0       5750.0
# 342              45.2             14.8              212.0       5200.0
# 343              49.9             16.1              213.0       5400.0
#
# [334 rows x 4 columns]

# %%
# Sacamos la matriz de correlación lineal
matriz = df_filtrado.corr()
matriz
# Out:
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.228640           0.652126
# culmen_depth_mm           -0.228640         1.000000          -0.578730
# flipper_length_mm          0.652126        -0.578730           1.000000
# body_mass_g                0.589066        -0.472987           0.873211
#
#                    body_mass_g
# culmen_length_mm      0.589066
# culmen_depth_mm      -0.472987
# flipper_length_mm     0.873211
# body_mass_g           1.000000

# %%
import seaborn as sns

# %%
# Usamos seaborn para realizar la gráfica del Heatmap
sns.heatmap(
    matriz,
    cmap='Blues',
    square=True,
    annot=True # Se pone el valor de correlación dentro de la casilla
)
# Out:
# <Axes: >

# %%
# Usamos una paleta de colores divergentes 
sns.heatmap(
    matriz,
    cmap='vlag_r', # "vlag" es la paleta de colores, si usamos "_r"
    square=True,
    annot=True # Se pone el valor de correlación dentro de la casilla
)
# Out:
# <Axes: >
