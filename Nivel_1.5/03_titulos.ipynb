# %% [markdown]
# ## Títulos
# Texto en grande que aparece (usualmente) encima del gráfico.
# - No debería contener más de 10 palabras.
# - Puede estar acompañado de un subtítulo si el gráfico necesita más contexto. Tampoco debería tener más de 10 - 15 palabras.
# - Cada eje del gráfico también siempre tiene que estar acompañado por un título que explique la variable que codifica.

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/tiendas_procesado.csv', index_col='fecha')
df
# Out:
#              DAIRY          MEATS       SEAFOOD
# fecha
# 2015-01  1134521.0  543117.728891  40465.835012
# 2015-02  1020747.0  498735.076839  36066.561003
# 2015-03  1234851.0  546517.159221  43808.473074
# 2015-04  1181180.0  522304.280744  39983.471003
# 2015-05  1293308.0  591691.899734  42506.832015
# 2015-06  1243588.0  565014.130035  38780.552004
# 2015-07  1244815.0  594903.677368  38535.588006
# 2015-08  1263428.0  581214.143026  37767.580998
# 2015-09  1224619.0  562711.633157  41906.374010
# 2015-10  1314827.0  580788.361242  41423.962963
# 2015-11  1283672.0  535908.927954  38823.761011
# 2015-12  1394582.0  567381.391078  33728.276973

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use(
    'ggplot'
)

ax = df.plot.line(
    figsize=(10, 5),
    title='Ventas de 3 tipos de productos en el año 2015'
)

# Para nombrar el eje X
ax.set_xlabel(
    'Período',
    loc='center'
)

# Para nombrar el eje Y
ax.set_ylabel(
    'Ventas (en millones de dólares)',
    loc='center'
)
# Out:
# Text(0, 0.5, 'Ventas (en millones de dólares)')

# %% [markdown]
# #### Seaborn

# %%
import seaborn as sns

# %%
plt.figure(
    figsize=(8, 4)
)

plt.title('Ventas de 3 tipos de productos en el año 2015')
plt.xlabel('Periíodo')
plt.ylabel('Ventas (en millones de dólares)')

sns.set_style('ticks')
sns.set_theme('paper')

ax = sns.lineplot(
    data=df
)

# %%
# Otra forma

plt.figure(
    figsize=(8, 4)
)

plt.title('Ventas de 3 tipos de productos en el año 2015')
plt.xlabel('Periíodo')
plt.ylabel('Ventas (en millones de dólares)')

sns.set_style('ticks')
sns.set_theme('paper')

ax = sns.lineplot(
    data=df
)

ax.set(
    xlabel='X LABEL!',
    ylabel='Y LABEL!',
    title='TITULO!'
)
# Out:
# [Text(0.5, 0, 'X LABEL!'), Text(0, 0.5, 'Y LABEL!'), Text(0.5, 1.0, 'TITULO!')]

# %% [markdown]
# #### Plotly

# %%
import plotly.express as px

# %%
fig = px.line(
    df,
    width=800,
    height=500,
    template='ggplot2',
    title='Ventas de 3 tipos de productos por año',
    labels={
        'fecha': 'Período',
        'value': 'Ventas en millones de $',
        'variable': 'Tipo de producto'
    }
)

fig.show()

# %%
# Otra forma

fig = px.line(
    df,
    width=800,
    height=500,
    template='ggplot2',
    title='Ventas de 3 tipos de productos por año',
    labels={
        'fecha': 'Período',
        'value': 'Ventas en millones de $',
        'variable': 'Tipo de producto'
    }
)

fig.update_layout(
    xaxis_title='PERÍODO!!',
    yaxis_title='VENTAS!!',
)

fig.show()
